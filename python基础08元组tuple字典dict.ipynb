# %% [markdown]
# # 元组 tuple
# - 元组的定义：
#   - 元组是不可改变的序列，同list一样，元组是可以存入任意类型的容器
# - 元组的表示方法：
#   - 用小括号（）括起来，单个元素括起来后加逗号（，）区分单个对象还元组
# - 创建空元组的字面值
#    - t = () #t绑定空元组
# - 创建非空元组
#       t = 200,
#       t = (20,)
#       t = (1,2,3)
#       t = 100, 200, 300
# - type(x)  函数用来返回 x 的类型
# - 元组的错误示例:
#       t = (20)
#       x, y, z = 100, 200, 300  # 序列赋值
#       x, y, z = (100, 200, 300)  # 序列赋值
#       x, y, z = [100, 200, 300]  # 序列赋值
#       x, y, z = "ABC"  # 序列赋值
# - 元组的构造(创建)函数tuple
#   - tuple()          生成一个空元组，等于同()
#   - tuple(iterable)  用可迭代对象生成一个元组
#   - 示例：
#     - t = tuple()
#     - t = tuple([2,3,4])
#     - t = tuple(range(10))
# - 元组的运算：
#       + 加号用于元组的拼接操作
#       * 乘号 用于用原元组生成重复的元组
#   - 示例：
#         t = (1,2,3) + (4,5,6)  # t = (1,2,3,4,5,6)
#         t = (1,2) * 3  # t = (1,2,1,2,1,2)
#         t = (1,2,3)
#         t += (4,5,6) # t = (1,2,3,4,5,6)
#         t *= 2      #  t = (1, 2, 3, 1, 2, 3)
#   - 比较运算
#         < <= > >= == !=
#   - in / not in 运算
# - 索引 和 切片
#   - 元组的索引和切片等同于列表的索引和切片
#   - 元组的切片返回一个元组
#   - 元组不能索引赋值和切片赋值
# - 元组的方法：
#   - T.count(value)  返回元素个数（同list.count)
#   - T.index(value, [start, [stop]]) 返回某个元素在元组的索引位置（同list.index)
# - 序列的种类：
#   - 字符串str,列表list,元组tuple
#   - 字节串bytes,字节数组bytearray
# - 能用于序列的函数总结：
#       len(x)
#       max(x)
#       min(x)
#       sum(x)
#       any(x)
#       all(x)
#       str(obj)  将对象序列化为字符串
#       list(iterable)
#       tuple(iterable)
#       reversed(seq)  返回反向顺序的迭代器对象
#       sorted(iterable, reverse=False) 返回已排序的列表

# %%
'''
练习：
  生成一个1～9的平方的元组，元组如下：
  （1,4,9....81)
'''
L = [i**2 for i in range(1,10)] 
t = tuple(L)
print(t)
# Out:
# (1, 4, 9, 16, 25, 36, 49, 64, 81)

# %% [markdown]
# # 字典 dict
# - 什么是字典
#   - 字典是一种可变的容器,可以存储任意类型的数据
#   - 字典中的每个数据都是用'键'进行索引的，而不像序列可以用下标(index)来进行索引
#   - 字典中的数据没有先后顺序关系, 字典的存储是无序的
#   - 字典中的数据以键(key)-值(value) 对的形式进行映射存储
#   - 字典的键不能重复，具只能用"不可变类型"作为字典的键
# - 字典的字面值表示方式：
#   - 字典的表示方式以 {} 括起来,以冒号(:) 分隔键-值对, 各键-值对之间用逗号(,)分割开
# - 创建空字典:
#       d = {}  # d绑定空字典
# - 创建非空字典：
#       d = {'name': 'tarena', 'age': 16}
#       d = {'year': 2018, 'month': 4, 'day':1}
# - 字典的构造函数dict
#   - dict()   生成一个空字典，等同于 {}
#   - dict(iterable)  用可迭代对象初始化一个字典
#   - dict(**kwargs)  用命名关键字传参形式生成一个字典
# - 示例：
#       d = dict()
#       d = dict([('name', 'tarena'), ('age', 15)])
#       d = dict(name='tarena', age=15)
# - 字典的基本操作：
#   - 字典的键索引
#         用[]运算符可以获取和修改键所对应的值
#   - 语法:
#         字典[键]
#   - 示例：
#         >>> d = {'name': 'tarena', 'age': 15}
#         >>> d['name']
#         'tarena'
#         >>> d['age']
#         15
#   - 键索引赋值说明：
#     - 当键不存在时，创建键并绑定对应的值
#     - 当键存在时，修改键绑定的对象
#   - 删除字典元素del语句
#     - del语句可以用来删除字典的键
#     - 语法：
#         del 字典[键]
#     - 示例:
#           d = {'name': 'tarena', 'age': 16}
#           del d['age'] # 删除'age'这个键
# - in 运算符（成员资格判断运算符）
#  - 可以用in运算符来判断一个键是否在字典中，如果存在则反回True ,否则返回False
#  - not in 与 in 相反
# - 示例：
#       d = {1: "一", 2: "二"}
#       1 in d      # True
#       2 in d      # True
#       2 not in d  # False
#       8 not in d  # True
#       8 in d      # False
#       '一' in d   # False
# - 字典的迭代访问：
#   - 字典是可迭代对象，字典只能对键进行迭代访问
#   - 示例：
#         d = {'name': '小张', 'birthday': (2008,8,8)}
#         for k in d:
#             print(k)

# %%
'''
练习：
  写程序，实现以下要求
  1.将如下数据形成一个字典 seasons
     键        值
     1       ‘春季有1,2,3月’
     2       ‘夏季有4,5,6月’
     3       ‘秋季有7,8,9月’
     4       ‘冬季有10,11,12月’
'''
d = {1:'春季有1,2,3月',2:'夏季有4,5,6月',3:'秋季有7,8,9月',4:'冬季有10,11,12月'}
'''
  2.让用户输入一个整数代表季度，打印这个季度的信息，如果用户输入的信息不在字典里，则提示信息不存在
'''
n = int(input("请输入季度："))
if n in d:
    print(d[n])
else:
    print("你输入信息不存在")
# Out:
# 请输入季度：4
# 冬季有10,11,12月

# %% [markdown]
# - 可以用于字典的内建（built- in)函数
#   - len(x)  返回字典的键值对的个数
#   - max(x)  返回字典的键的最大值
#   - min(x)  返回字典的键的最小值
#   - sum(x)  返回字典的所有键的和
#   - any(x)  对所有键进行真值测试，有一个为True结果为True
#   - all(x)  对所有键进行真值测试，所有为True才为True
# - 字典推导式:
#   - 作用：
#     - 用可迭代对象生成字典
#   - 语法:
#         {键表达式 : 值表达式 for 变量 in 可迭代对象 [if 真值表达式]}
#         注: []的内容代表可省略
#
#   - 示例:
#          生成一个字典，键为10以内的数字,值为键的平方
#          d = {x : x ** 2 for x in range(10)}
# - 字典 VS 列表
#       1. 都是可变对象
#       2. 索引方式不同, 列表用整数索引，字典用键索引
#       3. 字典的查找速度可能会快于列表(重要)
#       4. 列表的存储是有序的，字典的存储是无序的
# - 列表和字典 的内部存储原理
#   - 列表，顺序存储
#   - 字典，映射存储

# %%
'''
输入一段字符串，打印出这个字符串中出现过的字符及字符出现过的次数
输出：
 a:4次
 b:3次
 c:1次
 d:2次
'''
# 方法1
s = input('请输入字符串：')
L = [] #此列表用来存储出现过的字符
for ch in s:
    if ch not in L:
        L.append(ch)
for ch in L:
    print(ch,":",s.count(ch),"次")

# 方法2
l = {}
z = input('请输入字符串：')
for i in z:
    l[i] = z.count(i)
for k,v in l.items():
    print(k,":",v,"次",sep="")

# %%
'''练习：
  1. 有字符串列表如下:
      L = ["tarena", 'xiaozhang', 'hello']
    用推导式生成如下字典:
      d = {"tarena":6, 'xiaozhang':9, 'hello':5}
    注: 字典的值为键的长度
'''
L = ["tarena", 'xiaozhang', 'hello']
d = {x:len(x) for x in L }
print(d)
'''
2. 有两个列表：
    no = [1001, 1002, 1003, 1004]
    names = ['Tom', 'Jerry', 'Spike', 'Tyke']
    用no中的编码为作为键，以names中的字符串作为值，生成相应的字典
    提示 : range(4)来生成索引
'''
no = [1001, 1002, 1003, 1004]
names = ['Tom', 'Jerry', 'Spike', 'Tyke']
l = {no[i]:names[i] for i in range(len(no))}
d = {n:names[no.index(n)] for n in no}
print(l)
print(d)
# Out:
# {'tarena': 6, 'xiaozhang': 9, 'hello': 5}
# {1001: 'Tom', 1002: 'Jerry', 1003: 'Spike', 1004: 'Tyke'}

# %%
'''
练习：
1.输入一些单词和解释，将单词作为键，将解释作为值，将这些数据输入到字典中，当输入空的单词时结束输入
然后输入查询的单词，给出单词对应的解释
'''
z = {}
while True:
    n = input("请输入单词：")
    if not n:
        break
    s = input("请输入单词的解释：")
    z[n] = s
c = input("请输入单词：")
print(z.get(c))
# Out:
# 请输入单词：
# 请输入单词：
# None

# %%
'''
(重要)
输入任意个学生的信息：
   学生信息:
   姓名（字符串 str)
   年龄（整数 int)
   成绩（整数 int）
   当输入学生姓名为空时结束输入
   1）将每个学生的信息形成字典，存于列表中：
   2）以表格的形式打印所有学生的信息，如下：
   +-----------+----------+--------+
   |    name   |    age   | score  |
   +-----------+----------+--------+
   |           |          |        |
   |           |          |        |
   +-----------+----------+--------+
'''
L = []
while True:
    z = {}
    z["name"] = input('请输入姓名：')
    if not z["name"]:
        break
    z["age"] = int(input('请输入年龄：'))
    z["score"] = int(input('请输入成绩：'))
    L.append(z)
print(L)
a = "+"+"-"*13+"+"+"-"*13+"+"+"-"*13+"+"
print(a)
print("|"+"name".center(13)+"|"+"age".center(13)+"|"+"score".center(13)+"|")
print(a)
for i in L:
    print("|"+i["name"].center(13)+"|"+str(i["age"]).center(13)+"|"+str(i["score"]).center(13)+"|")
print(a)
